# %%
# nn.Module - base class for neural network modules

import torch
import torch.nn as nn

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    ## Define the layers
    self.layer1 = nn.Linear(128, 32) # i/p and o/p for the layer
    self.layer2 = nn.Linear(32, 16)
    self.layer3 = nn.Linear(16, 1)
  
  def forward(self, features):
    # input = (32, 128)
    x = self.layer1(features) # (32, 32)
    print(x.shape)
    x = self.layer2(x)
    x = self.layer3(x) #(32,1)
    return x

# %%
model = Model()
features = torch.rand(2, 128) # 2 samples of 128 features each
print(features)
# Out:
# tensor([[7.1785e-01, 3.0715e-01, 7.4500e-01, 8.7050e-02, 7.0203e-01, 2.8629e-01,
#          5.4384e-02, 7.3192e-01, 9.9132e-01, 8.7862e-01, 3.9889e-01, 3.3539e-01,
#          3.6932e-01, 8.1527e-02, 3.9305e-01, 5.2936e-01, 8.7396e-01, 6.1016e-01,
#          5.0060e-01, 9.3523e-02, 5.6001e-01, 1.2756e-01, 3.6780e-01, 1.8677e-01,
#          3.5293e-01, 3.3044e-01, 6.3215e-01, 4.4571e-01, 2.7731e-01, 7.6517e-01,
#          1.5078e-02, 6.6799e-01, 8.1407e-01, 3.3100e-01, 4.3118e-01, 4.1188e-01,
#          5.3604e-02, 6.2597e-01, 4.0414e-03, 1.0191e-01, 9.1235e-01, 4.3379e-01,
#          3.5992e-01, 7.8973e-01, 9.4796e-01, 1.7839e-01, 8.2060e-01, 6.2046e-01,
#          7.7690e-01, 3.0514e-01, 9.0208e-01, 6.9558e-01, 5.3467e-02, 5.9833e-01,
#          2.6023e-01, 8.8544e-01, 1.6512e-01, 3.8830e-01, 8.8057e-01, 1.0593e-01,
#          1.3892e-02, 3.1182e-01, 6.6653e-01, 3.4013e-02, 6.0863e-01, 1.0169e-01,
#          2.6277e-01, 6.8109e-01, 7.1525e-02, 8.2316e-02, 5.0534e-01, 8.9525e-01,
#          9.2301e-01, 5.5821e-02, 4.2555e-01, 3.5461e-01, 3.3182e-02, 2.3780e-01,
#          8.3459e-01, 4.5274e-01, 8.8475e-02, 4.0364e-01, 5.8147e-01, 9.7060e-01,
#          1.7482e-01, 1.9185e-01, 8.2371e-02, 7.0366e-01, 2.3714e-01, 4.7067e-02,
#          2.7491e-01, 9.6803e-01, 3.5128e-02, 5.7688e-01, 6.0910e-01, 3.0439e-01,
#          5.2413e-01, 7.7344e-01, 7.7384e-01, 9.9704e-02, 1.7429e-01, 3.2203e-01,
#          5.7752e-01, 4.0496e-01, 9.0909e-01, 9.2536e-02, 8.9711e-02, 3.2153e-01,
#          1.7574e-01, 1.8776e-01, 6.5077e-02, 3.2349e-01, 9.4169e-01, 3.4408e-01,
#          7.0992e-01, 9.0428e-01, 1.2497e-01, 8.9837e-01, 7.8659e-01, 5.7696e-01,
#          3.5733e-01, 1.9304e-01, 1.9836e-01, 9.7411e-01, 7.1822e-01, 8.2764e-01,
#          9.7082e-02, 8.2545e-01],
#         [6.2725e-01, 9.9635e-01, 1.0247e-01, 7.4309e-01, 9.9538e-01, 7.7286e-01,
#          6.3943e-01, 2.9691e-01, 6.3521e-02, 9.7198e-01, 1.9285e-01, 4.9627e-02,
#          1.4776e-02, 9.3056e-02, 2.8390e-01, 2.7147e-01, 9.8585e-01, 5.0588e-01,
#          2.9507e-01, 1.6950e-02, 7.3961e-01, 1.9318e-01, 8.8365e-01, 2.5128e-01,
#          6.8285e-02, 9.3278e-01, 9.0867e-01, 5.8577e-01, 8.7678e-01, 3.3476e-01,
#          6.3210e-01, 3.8660e-01, 7.0035e-01, 4.9742e-01, 8.7265e-01, 5.1344e-01,
#          2.3089e-01, 1.5049e-01, 7.7066e-01, 3.5196e-01, 1.3619e-01, 5.4540e-02,
#          4.7049e-01, 8.6767e-01, 8.6283e-01, 6.2813e-01, 8.5583e-01, 2.9759e-01,
#          7.4618e-02, 1.5138e-01, 8.8967e-01, 7.3785e-01, 2.5173e-01, 2.4961e-01,
#          9.0277e-01, 7.8857e-01, 3.1819e-01, 2.3366e-01, 4.5125e-01, 7.5882e-01,
#          7.7316e-01, 9.6347e-01, 4.3819e-01, 3.7039e-01, 6.2493e-01, 1.4530e-01,
#          4.3029e-01, 7.5024e-04, 8.6939e-01, 7.2660e-01, 3.0744e-01, 2.9870e-01,
#          2.9332e-01, 2.7700e-01, 9.5278e-01, 1.0844e-01, 2.6461e-01, 6.5955e-01,
#          9.9303e-02, 3.1103e-01, 3.2551e-01, 8.4400e-01, 6.7472e-01, 3.3219e-01,
#          1.0509e-01, 1.0257e-01, 8.2147e-01, 4.9528e-01, 1.5213e-02, 3.0406e-01,
#          5.0508e-01, 2.8644e-02, 1.8409e-01, 7.4650e-02, 1.5689e-01, 5.2459e-01,
#          1.0038e-01, 1.6460e-02, 4.5317e-01, 8.7227e-01, 9.7684e-01, 8.8640e-01,
#          8.7753e-02, 7.7495e-01, 9.5213e-01, 8.9762e-01, 3.3604e-01, 2.8138e-01,
#          6.7019e-01, 3.6515e-01, 1.8947e-01, 9.6463e-01, 5.6889e-01, 6.0133e-01,
#          5.0756e-01, 2.0601e-01, 9.5802e-01, 9.7549e-01, 6.4139e-01, 1.3018e-01,
#          9.5353e-01, 7.8550e-01, 3.7579e-01, 1.2472e-01, 4.4420e-01, 4.7944e-01,
#          2.0886e-01, 7.5915e-01]])

# %%
model(features)
# Out:
# torch.Size([2, 32])
# tensor([[ 0.0280],
#         [-0.0776]], grad_fn=<AddmmBackward0>)

# %%
features.device
# Out:
# device(type='cpu')

# %%
features = features.to("cuda")
model = Model()
model.to("cuda")
model(features)
# Out:
# torch.Size([2, 32])
# tensor([[0.3481],
#         [0.2780]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
class Model(nn.Module):
  def __init__(self):
    super().__init__()
    ## Define the base layer
    self.base = nn.Sequential(
    nn.Linear(128, 32), # layers will be applied sequentially
    nn.Linear(32, 16),
    nn.Linear(16, 1)
)
    
  
  def forward(self, features):
    # input = (32, 128)
    x = self.base(features) # (32, 1)
    #print(x.shape)
    return x

# %%
features = features.to("cuda")
model = Model()
model.to("cuda")
model(features)
# Out:
# tensor([[-0.0684],
#         [-0.2144]], device='cuda:0', grad_fn=<AddmmBackward0>)
